# %%
import os
from dotenv import load_dotenv
from langchain_together import ChatTogether

# 🔸 Modern Core Imports
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.tools import Tool

# 🔐 Load API keys
load_dotenv(dotenv_path=".env")
together_api_key = os.getenv("TOGETHER_API_KEY")

# 🔸 Initialize the LLM
llm = ChatTogether(
    model="meta-llama/Meta-Llama-3-8B-Instruct-Lite", 
    temperature=0,
    together_api_key=together_api_key
)

# ✅ Tool 1: Simple QA Tool (Modernized)
qa_prompt = PromptTemplate.from_template("Answer clearly: {question}")
qa_chain = qa_prompt | llm | StrOutputParser()

qa_tool = Tool(
    name="Simple QA",
    func=lambda q: qa_chain.invoke({"question": q}),
    description="Answer factual questions clearly"
)

# ✅ Tool 2: Summarizer Tool (Modernized)
summary_prompt = PromptTemplate.from_template("Summarize the following text:\n\n{text}")
summary_chain = summary_prompt | llm | StrOutputParser()

summary_tool = Tool(
    name="Summarizer",
    func=lambda t: summary_chain.invoke({"text": t}),
    description="Summarizes input text"
)

# 🔧 Tool usage examples
qa_query = "What is LangGraph in LangChain?"
summary_text = """
LangGraph is a library built on top of LangChain that helps developers create stateful, multi-step agents 
as graphs. Each node represents a step like calling an LLM or a tool. It's ideal for advanced AI workflows.
"""

# 🚀 Run tools manually using .invoke() 
# Notice how we only pass the plain string variable here, not a dictionary!
print("\n🧠 Simple QA Tool Output:\n", qa_tool.invoke(qa_query))
print("\n📝 Summarizer Tool Output:\n", summary_tool.invoke(summary_text))
# Out:
# 🧠 Simple QA Tool Output:
#  According to the LangChain documentation, LangGraph is a sub-component of LangChain that represents a graph-based language model. It is designed to leverage the strengths of both graph-based and sequence-based language models to generate more accurate and informative responses.
#
# In LangGraph, a graph is constructed to represent the relationships between entities, concepts, and ideas in a given text. This graph is then used to generate responses that are more informed and context-aware. LangGraph is particularly useful for tasks that require a deep understanding of the input text, such as answering complex questions, generating summaries, and providing explanations.
#
# By combining the strengths of graph-based and sequence-based language models, LangGraph is designed to improve the accuracy and coherence of generated responses, making it a powerful tool for a wide range of natural language processing tasks.
#
# 📝 Summarizer Tool Output:
#  LangGraph is a library that allows developers to create complex, multi-step AI workflows as graphs. Each node in the graph represents a specific step, such as calling a Large Language Model (LLM) or a tool, and is designed for advanced AI applications.
